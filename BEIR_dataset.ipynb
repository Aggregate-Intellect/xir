# %% [markdown]
# <a href="https://colab.research.google.com/github/ChenKua/xir/blob/main/beir_haystack_document_retrieval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # installation

# %%
# !pip install beir
# !pip install tensorflow-text
# !pip install --upgrade pip
# !pip install git+https://github.com/deepset-ai/haystack.git#egg=farm-haystack[colab,faiss]

# %%
from beir import util, LoggingHandler
from beir.retrieval import models
from beir.datasets.data_loader import GenericDataLoader
from beir.retrieval.evaluation import EvaluateRetrieval
from beir.retrieval.search.dense import DenseRetrievalExactSearch as DRES

import logging
import pathlib, os

from typing import List
import requests
import pandas as pd
from haystack import Document
from haystack.document_stores import FAISSDocumentStore
from haystack.nodes import RAGenerator, DensePassageRetriever
from haystack.utils import fetch_archive_from_http

# %% [markdown]
# # BEIR dataset
#
# * scifact/
#     * corpus.jsonl
#     * queries.jsonl
#     * qrels/
#         * train.tsv
#         * dev.tsv
#         * test.tsv

# %%
logging.basicConfig(format='%(asctime)s - %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S',
                    level=logging.INFO,
                    handlers=[LoggingHandler()],
                    force=True)

dataset = "scifact"
url = "https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/{}.zip".format(dataset)
out_dir = os.path.join(os.getcwd(), "datasets")
data_path = util.download_and_unzip(url, out_dir)
print("Dataset downloaded here: {}".format(data_path))
# Out:
# /content/datasets/scifact.zip:   0%|          | 0.00/2.69M [00:00<?, ?iB/s]
# Dataset downloaded here: /content/datasets/scifact

# %%
from beir.datasets.data_loader import GenericDataLoader

data_path = "datasets/scifact"
corpus, queries, qrels = GenericDataLoader(data_path).load(split="test") # or split = "train" or "dev"
# Out:
#   0%|          | 0/5183 [00:00<?, ?it/s]

# %%
pd_corpus = pd.DataFrame(corpus)
pd_corpus = pd_corpus.transpose()
pd.DataFrame(pd_corpus)
# Out:
#                                                                                       text  \
# 4983       Alterations of the architecture of cerebral white matter in the developing h...
# 5836       Myelodysplastic syndromes (MDS) are age-dependent stem cell malignancies tha...
# 7912       ID elements are short interspersed elements (SINEs) found in high copy numbe...
# 18670      DNA methylation plays an important role in biological processes in human hea...
# 19238      Two human Golli (for gene expressed in the oligodendrocyte lineage)-MBP (for...
# ...                                                                                    ...
# 195689316  BACKGROUND The main associations of body-mass index (BMI) with overall and c...
# 195689757  A key aberrant biological difference between tumor cells and normal differen...
# 196664003  A signaling pathway transmits information from an upstream system to downstr...
# 198133135  AIMS Trabecular bone score (TBS) is a surrogate indicator of bone microarchi...
# 198309074  Introduction: Among the inflammatory mediators involved in the pathogenesis ...
#
#                                                                                      title
# 4983       Microstructural development of human newborn cerebral white matter assessed ...
# 5836                      Induction of myelodysplasia by myeloid-derived suppressor cells.
# 7912       BC1 RNA, the transcript from a master gene for ID element amplification, is ...
# 18670                        The DNA Methylome of Human Peripheral Blood Mononuclear Cells
# 19238      The human myelin basic protein gene is included within a 179-kilobase transc...
# ...                                                                                    ...
# 195689316  Body-mass index and cause-specific mortality in 900 000 adults: collaborativ...
# 195689757                       Targeting metabolic remodeling in glioblastoma multiforme.
# 196664003  Signaling architectures that transmit unidirectional information despite ret...
# 198133135  Association between pre-diabetes, type 2 diabetes and trabecular bone score:...
# 198309074  Adhesion molecules and chemokines: relation to anthropometric, body composit...
#
# [5183 rows x 2 columns]

# %%
pd_qrels = pd.DataFrame(qrels)
pd.DataFrame(pd_qrels)
# Out:
#             1    3    5   13   36  42   48  49  50  51  ...  1359  1362  1363  \
# 31715818  1.0  NaN  NaN  NaN  NaN NaN  NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 14717500  NaN  1.0  NaN  NaN  NaN NaN  NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 13734012  NaN  NaN  1.0  NaN  NaN NaN  1.0 NaN NaN NaN  ...   NaN   NaN   NaN
# 1606628   NaN  NaN  NaN  1.0  NaN NaN  NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 5152028   NaN  NaN  NaN  NaN  1.0 NaN  NaN NaN NaN NaN  ...   NaN   NaN   NaN
# ...       ...  ...  ...  ...  ...  ..  ...  ..  ..  ..  ...   ...   ...   ...
# 2425364   NaN  NaN  NaN  NaN  NaN NaN  NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 17755060  NaN  NaN  NaN  NaN  NaN NaN  NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 306006    NaN  NaN  NaN  NaN  NaN NaN  NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 23895668  NaN  NaN  NaN  NaN  NaN NaN  NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 17717391  NaN  NaN  NaN  NaN  NaN NaN  NaN NaN NaN NaN  ...   NaN   NaN   NaN
#
#           1368  1370  1379  1382  1385  1389  1395
# 31715818   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 14717500   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13734012   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1606628    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5152028    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...        ...   ...   ...   ...   ...   ...   ...
# 2425364    1.0   1.0   NaN   NaN   NaN   NaN   NaN
# 17755060   NaN   NaN   NaN   1.0   NaN   NaN   NaN
# 306006     NaN   NaN   NaN   NaN   1.0   NaN   NaN
# 23895668   NaN   NaN   NaN   NaN   NaN   1.0   NaN
# 17717391   NaN   NaN   NaN   NaN   NaN   NaN   1.0
#
# [283 rows x 300 columns]

# %%
pd_queries = pd.DataFrame(queries,queries.items())
pd.DataFrame(pd_queries)
# Out:
#                                                                                                                                            1  \
# 1    0-dimensional biomaterials show inductive properties.                             0-dimensional biomaterials show inductive properties.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  0-dimensional biomaterials show inductive properties.
# 5    1/2000 in UK have abnormal PrP positivity.                                        0-dimensional biomaterials show inductive properties.
# 13   5% of perinatal mortality is due to low birth weight.                             0-dimensional biomaterials show inductive properties.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               0-dimensional biomaterials show inductive properties.
# ...                                                                                                                                      ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  0-dimensional biomaterials show inductive properties.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                0-dimensional biomaterials show inductive properties.
# 1385 cSMAC formation enhances weak ligand signalling.                                  0-dimensional biomaterials show inductive properties.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            0-dimensional biomaterials show inductive properties.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  0-dimensional biomaterials show inductive properties.
#
#                                                                                                                                                                      3  \
# 1    0-dimensional biomaterials show inductive properties.                             1,000 genomes project enables mapping of genetic sequence variation consisti...
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  1,000 genomes project enables mapping of genetic sequence variation consisti...
# 5    1/2000 in UK have abnormal PrP positivity.                                        1,000 genomes project enables mapping of genetic sequence variation consisti...
# 13   5% of perinatal mortality is due to low birth weight.                             1,000 genomes project enables mapping of genetic sequence variation consisti...
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               1,000 genomes project enables mapping of genetic sequence variation consisti...
# ...                                                                                                                                                                ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  1,000 genomes project enables mapping of genetic sequence variation consisti...
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                1,000 genomes project enables mapping of genetic sequence variation consisti...
# 1385 cSMAC formation enhances weak ligand signalling.                                  1,000 genomes project enables mapping of genetic sequence variation consisti...
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            1,000 genomes project enables mapping of genetic sequence variation consisti...
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  1,000 genomes project enables mapping of genetic sequence variation consisti...
#
#                                                                                                                                 5  \
# 1    0-dimensional biomaterials show inductive properties.                             1/2000 in UK have abnormal PrP positivity.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  1/2000 in UK have abnormal PrP positivity.
# 5    1/2000 in UK have abnormal PrP positivity.                                        1/2000 in UK have abnormal PrP positivity.
# 13   5% of perinatal mortality is due to low birth weight.                             1/2000 in UK have abnormal PrP positivity.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               1/2000 in UK have abnormal PrP positivity.
# ...                                                                                                                           ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  1/2000 in UK have abnormal PrP positivity.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                1/2000 in UK have abnormal PrP positivity.
# 1385 cSMAC formation enhances weak ligand signalling.                                  1/2000 in UK have abnormal PrP positivity.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            1/2000 in UK have abnormal PrP positivity.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  1/2000 in UK have abnormal PrP positivity.
#
#                                                                                                                                           13  \
# 1    0-dimensional biomaterials show inductive properties.                             5% of perinatal mortality is due to low birth weight.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  5% of perinatal mortality is due to low birth weight.
# 5    1/2000 in UK have abnormal PrP positivity.                                        5% of perinatal mortality is due to low birth weight.
# 13   5% of perinatal mortality is due to low birth weight.                             5% of perinatal mortality is due to low birth weight.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               5% of perinatal mortality is due to low birth weight.
# ...                                                                                                                                      ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  5% of perinatal mortality is due to low birth weight.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                5% of perinatal mortality is due to low birth weight.
# 1385 cSMAC formation enhances weak ligand signalling.                                  5% of perinatal mortality is due to low birth weight.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            5% of perinatal mortality is due to low birth weight.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  5% of perinatal mortality is due to low birth weight.
#
#                                                                                                                                                         36  \
# 1    0-dimensional biomaterials show inductive properties.                             A deficiency of vitamin B12 increases blood levels of homocysteine.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  A deficiency of vitamin B12 increases blood levels of homocysteine.
# 5    1/2000 in UK have abnormal PrP positivity.                                        A deficiency of vitamin B12 increases blood levels of homocysteine.
# 13   5% of perinatal mortality is due to low birth weight.                             A deficiency of vitamin B12 increases blood levels of homocysteine.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               A deficiency of vitamin B12 increases blood levels of homocysteine.
# ...                                                                                                                                                    ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  A deficiency of vitamin B12 increases blood levels of homocysteine.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                A deficiency of vitamin B12 increases blood levels of homocysteine.
# 1385 cSMAC formation enhances weak ligand signalling.                                  A deficiency of vitamin B12 increases blood levels of homocysteine.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            A deficiency of vitamin B12 increases blood levels of homocysteine.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  A deficiency of vitamin B12 increases blood levels of homocysteine.
#
#                                                                                                                                                                     42  \
# 1    0-dimensional biomaterials show inductive properties.                             A high microerythrocyte count raises vulnerability to severe anemia in homoz...
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  A high microerythrocyte count raises vulnerability to severe anemia in homoz...
# 5    1/2000 in UK have abnormal PrP positivity.                                        A high microerythrocyte count raises vulnerability to severe anemia in homoz...
# 13   5% of perinatal mortality is due to low birth weight.                             A high microerythrocyte count raises vulnerability to severe anemia in homoz...
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               A high microerythrocyte count raises vulnerability to severe anemia in homoz...
# ...                                                                                                                                                                ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  A high microerythrocyte count raises vulnerability to severe anemia in homoz...
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                A high microerythrocyte count raises vulnerability to severe anemia in homoz...
# 1385 cSMAC formation enhances weak ligand signalling.                                  A high microerythrocyte count raises vulnerability to severe anemia in homoz...
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            A high microerythrocyte count raises vulnerability to severe anemia in homoz...
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  A high microerythrocyte count raises vulnerability to severe anemia in homoz...
#
#                                                                                                                                                                    48  \
# 1    0-dimensional biomaterials show inductive properties.                             A total of 1,000 people in the UK are asymptomatic carriers of vCJD infection.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  A total of 1,000 people in the UK are asymptomatic carriers of vCJD infection.
# 5    1/2000 in UK have abnormal PrP positivity.                                        A total of 1,000 people in the UK are asymptomatic carriers of vCJD infection.
# 13   5% of perinatal mortality is due to low birth weight.                             A total of 1,000 people in the UK are asymptomatic carriers of vCJD infection.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               A total of 1,000 people in the UK are asymptomatic carriers of vCJD infection.
# ...                                                                                                                                                               ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  A total of 1,000 people in the UK are asymptomatic carriers of vCJD infection.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                A total of 1,000 people in the UK are asymptomatic carriers of vCJD infection.
# 1385 cSMAC formation enhances weak ligand signalling.                                  A total of 1,000 people in the UK are asymptomatic carriers of vCJD infection.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            A total of 1,000 people in the UK are asymptomatic carriers of vCJD infection.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  A total of 1,000 people in the UK are asymptomatic carriers of vCJD infection.
#
#                                                                                                                               49  \
# 1    0-dimensional biomaterials show inductive properties.                             ADAR1 binds to Dicer to cleave pre-miRNA.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  ADAR1 binds to Dicer to cleave pre-miRNA.
# 5    1/2000 in UK have abnormal PrP positivity.                                        ADAR1 binds to Dicer to cleave pre-miRNA.
# 13   5% of perinatal mortality is due to low birth weight.                             ADAR1 binds to Dicer to cleave pre-miRNA.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               ADAR1 binds to Dicer to cleave pre-miRNA.
# ...                                                                                                                          ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  ADAR1 binds to Dicer to cleave pre-miRNA.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                ADAR1 binds to Dicer to cleave pre-miRNA.
# 1385 cSMAC formation enhances weak ligand signalling.                                  ADAR1 binds to Dicer to cleave pre-miRNA.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            ADAR1 binds to Dicer to cleave pre-miRNA.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  ADAR1 binds to Dicer to cleave pre-miRNA.
#
#                                                                                                                            50  \
# 1    0-dimensional biomaterials show inductive properties.                             AIRE is expressed in some skin tumors.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  AIRE is expressed in some skin tumors.
# 5    1/2000 in UK have abnormal PrP positivity.                                        AIRE is expressed in some skin tumors.
# 13   5% of perinatal mortality is due to low birth weight.                             AIRE is expressed in some skin tumors.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               AIRE is expressed in some skin tumors.
# ...                                                                                                                       ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  AIRE is expressed in some skin tumors.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                AIRE is expressed in some skin tumors.
# 1385 cSMAC formation enhances weak ligand signalling.                                  AIRE is expressed in some skin tumors.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            AIRE is expressed in some skin tumors.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  AIRE is expressed in some skin tumors.
#
#                                                                                                                                                        51  \
# 1    0-dimensional biomaterials show inductive properties.                             ALDH1 expression is associated with better breast cancer outcomes.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  ALDH1 expression is associated with better breast cancer outcomes.
# 5    1/2000 in UK have abnormal PrP positivity.                                        ALDH1 expression is associated with better breast cancer outcomes.
# 13   5% of perinatal mortality is due to low birth weight.                             ALDH1 expression is associated with better breast cancer outcomes.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               ALDH1 expression is associated with better breast cancer outcomes.
# ...                                                                                                                                                   ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  ALDH1 expression is associated with better breast cancer outcomes.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                ALDH1 expression is associated with better breast cancer outcomes.
# 1385 cSMAC formation enhances weak ligand signalling.                                  ALDH1 expression is associated with better breast cancer outcomes.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            ALDH1 expression is associated with better breast cancer outcomes.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  ALDH1 expression is associated with better breast cancer outcomes.
#
#                                                                                        ...  \
# 1    0-dimensional biomaterials show inductive properties.                             ...
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  ...
# 5    1/2000 in UK have abnormal PrP positivity.                                        ...
# 13   5% of perinatal mortality is due to low birth weight.                             ...
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               ...
# ...                                                                                    ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  ...
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                ...
# 1385 cSMAC formation enhances weak ligand signalling.                                  ...
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            ...
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  ...
#
#                                                                                                                                                                   1359  \
# 1    0-dimensional biomaterials show inductive properties.                             Varenicline monotherapy is more effective after 12 weeks of treatment compar...
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  Varenicline monotherapy is more effective after 12 weeks of treatment compar...
# 5    1/2000 in UK have abnormal PrP positivity.                                        Varenicline monotherapy is more effective after 12 weeks of treatment compar...
# 13   5% of perinatal mortality is due to low birth weight.                             Varenicline monotherapy is more effective after 12 weeks of treatment compar...
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               Varenicline monotherapy is more effective after 12 weeks of treatment compar...
# ...                                                                                                                                                                ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  Varenicline monotherapy is more effective after 12 weeks of treatment compar...
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                Varenicline monotherapy is more effective after 12 weeks of treatment compar...
# 1385 cSMAC formation enhances weak ligand signalling.                                  Varenicline monotherapy is more effective after 12 weeks of treatment compar...
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            Varenicline monotherapy is more effective after 12 weeks of treatment compar...
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  Varenicline monotherapy is more effective after 12 weeks of treatment compar...
#
#                                                                                                                                         1362  \
# 1    0-dimensional biomaterials show inductive properties.                             Venules have a larger lumen diameter than arterioles.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  Venules have a larger lumen diameter than arterioles.
# 5    1/2000 in UK have abnormal PrP positivity.                                        Venules have a larger lumen diameter than arterioles.
# 13   5% of perinatal mortality is due to low birth weight.                             Venules have a larger lumen diameter than arterioles.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               Venules have a larger lumen diameter than arterioles.
# ...                                                                                                                                      ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  Venules have a larger lumen diameter than arterioles.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                Venules have a larger lumen diameter than arterioles.
# 1385 cSMAC formation enhances weak ligand signalling.                                  Venules have a larger lumen diameter than arterioles.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            Venules have a larger lumen diameter than arterioles.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  Venules have a larger lumen diameter than arterioles.
#
#                                                                                                                                                         1363  \
# 1    0-dimensional biomaterials show inductive properties.                             Venules have a thinner or absent smooth layer compared to arterioles.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  Venules have a thinner or absent smooth layer compared to arterioles.
# 5    1/2000 in UK have abnormal PrP positivity.                                        Venules have a thinner or absent smooth layer compared to arterioles.
# 13   5% of perinatal mortality is due to low birth weight.                             Venules have a thinner or absent smooth layer compared to arterioles.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               Venules have a thinner or absent smooth layer compared to arterioles.
# ...                                                                                                                                                      ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  Venules have a thinner or absent smooth layer compared to arterioles.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                Venules have a thinner or absent smooth layer compared to arterioles.
# 1385 cSMAC formation enhances weak ligand signalling.                                  Venules have a thinner or absent smooth layer compared to arterioles.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            Venules have a thinner or absent smooth layer compared to arterioles.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  Venules have a thinner or absent smooth layer compared to arterioles.
#
#                                                                                                                                      1368  \
# 1    0-dimensional biomaterials show inductive properties.                             Vitamin D deficiency effects the term of delivery.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  Vitamin D deficiency effects the term of delivery.
# 5    1/2000 in UK have abnormal PrP positivity.                                        Vitamin D deficiency effects the term of delivery.
# 13   5% of perinatal mortality is due to low birth weight.                             Vitamin D deficiency effects the term of delivery.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               Vitamin D deficiency effects the term of delivery.
# ...                                                                                                                                   ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  Vitamin D deficiency effects the term of delivery.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                Vitamin D deficiency effects the term of delivery.
# 1385 cSMAC formation enhances weak ligand signalling.                                  Vitamin D deficiency effects the term of delivery.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            Vitamin D deficiency effects the term of delivery.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  Vitamin D deficiency effects the term of delivery.
#
#                                                                                                                                      1370  \
# 1    0-dimensional biomaterials show inductive properties.                             Vitamin D deficiency is unrelated to birth weight.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  Vitamin D deficiency is unrelated to birth weight.
# 5    1/2000 in UK have abnormal PrP positivity.                                        Vitamin D deficiency is unrelated to birth weight.
# 13   5% of perinatal mortality is due to low birth weight.                             Vitamin D deficiency is unrelated to birth weight.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               Vitamin D deficiency is unrelated to birth weight.
# ...                                                                                                                                   ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  Vitamin D deficiency is unrelated to birth weight.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                Vitamin D deficiency is unrelated to birth weight.
# 1385 cSMAC formation enhances weak ligand signalling.                                  Vitamin D deficiency is unrelated to birth weight.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            Vitamin D deficiency is unrelated to birth weight.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  Vitamin D deficiency is unrelated to birth weight.
#
#                                                                                                                                                                   1379  \
# 1    0-dimensional biomaterials show inductive properties.                             Women with a higher birth weight are more likely to develop breast cancer la...
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  Women with a higher birth weight are more likely to develop breast cancer la...
# 5    1/2000 in UK have abnormal PrP positivity.                                        Women with a higher birth weight are more likely to develop breast cancer la...
# 13   5% of perinatal mortality is due to low birth weight.                             Women with a higher birth weight are more likely to develop breast cancer la...
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               Women with a higher birth weight are more likely to develop breast cancer la...
# ...                                                                                                                                                                ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  Women with a higher birth weight are more likely to develop breast cancer la...
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                Women with a higher birth weight are more likely to develop breast cancer la...
# 1385 cSMAC formation enhances weak ligand signalling.                                  Women with a higher birth weight are more likely to develop breast cancer la...
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            Women with a higher birth weight are more likely to develop breast cancer la...
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  Women with a higher birth weight are more likely to develop breast cancer la...
#
#                                                                                                                                                      1382  \
# 1    0-dimensional biomaterials show inductive properties.                             aPKCz causes tumour enhancement by affecting glutamine metabolism.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  aPKCz causes tumour enhancement by affecting glutamine metabolism.
# 5    1/2000 in UK have abnormal PrP positivity.                                        aPKCz causes tumour enhancement by affecting glutamine metabolism.
# 13   5% of perinatal mortality is due to low birth weight.                             aPKCz causes tumour enhancement by affecting glutamine metabolism.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               aPKCz causes tumour enhancement by affecting glutamine metabolism.
# ...                                                                                                                                                   ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  aPKCz causes tumour enhancement by affecting glutamine metabolism.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                aPKCz causes tumour enhancement by affecting glutamine metabolism.
# 1385 cSMAC formation enhances weak ligand signalling.                                  aPKCz causes tumour enhancement by affecting glutamine metabolism.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            aPKCz causes tumour enhancement by affecting glutamine metabolism.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  aPKCz causes tumour enhancement by affecting glutamine metabolism.
#
#                                                                                                                                    1385  \
# 1    0-dimensional biomaterials show inductive properties.                             cSMAC formation enhances weak ligand signalling.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  cSMAC formation enhances weak ligand signalling.
# 5    1/2000 in UK have abnormal PrP positivity.                                        cSMAC formation enhances weak ligand signalling.
# 13   5% of perinatal mortality is due to low birth weight.                             cSMAC formation enhances weak ligand signalling.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               cSMAC formation enhances weak ligand signalling.
# ...                                                                                                                                 ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  cSMAC formation enhances weak ligand signalling.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                cSMAC formation enhances weak ligand signalling.
# 1385 cSMAC formation enhances weak ligand signalling.                                  cSMAC formation enhances weak ligand signalling.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            cSMAC formation enhances weak ligand signalling.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  cSMAC formation enhances weak ligand signalling.
#
#                                                                                                                                                          1389  \
# 1    0-dimensional biomaterials show inductive properties.                             mTORC2 regulates intracellular cysteine levels through xCT inhibition.
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  mTORC2 regulates intracellular cysteine levels through xCT inhibition.
# 5    1/2000 in UK have abnormal PrP positivity.                                        mTORC2 regulates intracellular cysteine levels through xCT inhibition.
# 13   5% of perinatal mortality is due to low birth weight.                             mTORC2 regulates intracellular cysteine levels through xCT inhibition.
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               mTORC2 regulates intracellular cysteine levels through xCT inhibition.
# ...                                                                                                                                                       ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  mTORC2 regulates intracellular cysteine levels through xCT inhibition.
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                mTORC2 regulates intracellular cysteine levels through xCT inhibition.
# 1385 cSMAC formation enhances weak ligand signalling.                                  mTORC2 regulates intracellular cysteine levels through xCT inhibition.
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            mTORC2 regulates intracellular cysteine levels through xCT inhibition.
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  mTORC2 regulates intracellular cysteine levels through xCT inhibition.
#
#                                                                                                                                                                   1395
# 1    0-dimensional biomaterials show inductive properties.                             p16INK4A accumulation is  linked to an abnormal wound response caused by the...
# 3    1,000 genomes project enables mapping of genetic sequence variation consistin...  p16INK4A accumulation is  linked to an abnormal wound response caused by the...
# 5    1/2000 in UK have abnormal PrP positivity.                                        p16INK4A accumulation is  linked to an abnormal wound response caused by the...
# 13   5% of perinatal mortality is due to low birth weight.                             p16INK4A accumulation is  linked to an abnormal wound response caused by the...
# 36   A deficiency of vitamin B12 increases blood levels of homocysteine.               p16INK4A accumulation is  linked to an abnormal wound response caused by the...
# ...                                                                                                                                                                ...
# 1379 Women with a higher birth weight are more likely to develop breast cancer lat...  p16INK4A accumulation is  linked to an abnormal wound response caused by the...
# 1382 aPKCz causes tumour enhancement by affecting glutamine metabolism.                p16INK4A accumulation is  linked to an abnormal wound response caused by the...
# 1385 cSMAC formation enhances weak ligand signalling.                                  p16INK4A accumulation is  linked to an abnormal wound response caused by the...
# 1389 mTORC2 regulates intracellular cysteine levels through xCT inhibition.            p16INK4A accumulation is  linked to an abnormal wound response caused by the...
# 1395 p16INK4A accumulation is  linked to an abnormal wound response caused by the ...  p16INK4A accumulation is  linked to an abnormal wound response caused by the...
#
# [300 rows x 300 columns]

# %% [markdown]
# # Retriever
#
#
# *   BaseGraphRetriever(BaseComponent)
# *   BaseRetriever(BaseComponent)
# *   BM25Retriever(BaseRetriever)
# *   FilterRetriever(BM25Retriever)
# *   TfidfRetriever(BaseRetriever)
# *   DensePassageRetriever(BaseRetriever)
# *   TableTextRetriever(BaseRetriever)
# *   EmbeddingRetriever(BaseRetriever)
# *   Text2SparqlRetriever(BaseGraphRetriever)
#
# See documentation at: https://github.com/deepset-ai/haystack/blob/master/docs/_src/api/api/retriever.md

# %%
# from haystack.nodes import DensePassageRetriever

# retriever = DensePassageRetriever(
#     document_store=document_store,
#     query_embedding_model="facebook/dpr-question_encoder-single-nq-base",
#     passage_embedding_model="facebook/dpr-ctx_encoder-single-nq-base",
#     max_seq_len_query=64,
#     max_seq_len_passage=256,
#     batch_size=16,
#     use_gpu=True,
#     embed_title=True,
#     use_fast_tokenizers=True,
# )

# results = retriever.retrieve(corpus, queries)

from beir.retrieval.evaluation import EvaluateRetrieval
from beir.retrieval import models
from beir.retrieval.search.dense import DenseRetrievalExactSearch 

#### Dense Retrieval using SBERT (Sentence-BERT) ####
#### Provide any pretrained sentence-transformers model
#### The model was fine-tuned using cosine-similarity.
#### Complete list - https://www.sbert.net/docs/pretrained_models.html

model = DenseRetrievalExactSearch(models.SentenceBERT("msmarco-distilbert-base-v3"), batch_size=128)
retriever = EvaluateRetrieval(model, score_function="cos_sim")

#### Retrieve dense results (format of results is identical to qrels)
results = retriever.retrieve(corpus, queries)

# %%
logging.info("Retriever evaluation for k in: {}".format(retriever.k_values))
for k in retriever.k_values:
    ndcg, _map, recall, precision = retriever.evaluate(qrels, results, retriever.k_values)
    print("Retriever evaluation for k in: {}".format(k))
    print(ndcg, _map, recall, precision)
# Out:
# Retriever evaluation for k in: 1
# {'NDCG@1': 0.42333, 'NDCG@3': 0.48416, 'NDCG@5': 0.51037, 'NDCG@10': 0.53789, 'NDCG@100': 0.57592, 'NDCG@1000': 0.59134} {'MAP@1': 0.39944, 'MAP@3': 0.45935, 'MAP@5': 0.47679, 'MAP@10': 0.48894, 'MAP@100': 0.49742, 'MAP@1000': 0.49797} {'Recall@1': 0.39944, 'Recall@3': 0.52561, 'Recall@5': 0.58872, 'Recall@10': 0.67233, 'Recall@100': 0.846, 'Recall@1000': 0.96833} {'P@1': 0.42333, 'P@3': 0.19333, 'P@5': 0.13333, 'P@10': 0.07567, 'P@100': 0.0096, 'P@1000': 0.0011}
# Retriever evaluation for k in: 3
# {'NDCG@1': 0.42333, 'NDCG@3': 0.48416, 'NDCG@5': 0.51037, 'NDCG@10': 0.53789, 'NDCG@100': 0.57592, 'NDCG@1000': 0.59134} {'MAP@1': 0.39944, 'MAP@3': 0.45935, 'MAP@5': 0.47679, 'MAP@10': 0.48894, 'MAP@100': 0.49742, 'MAP@1000': 0.49797} {'Recall@1': 0.39944, 'Recall@3': 0.52561, 'Recall@5': 0.58872, 'Recall@10': 0.67233, 'Recall@100': 0.846, 'Recall@1000': 0.96833} {'P@1': 0.42333, 'P@3': 0.19333, 'P@5': 0.13333, 'P@10': 0.07567, 'P@100': 0.0096, 'P@1000': 0.0011}
# Retriever evaluation for k in: 5
# {'NDCG@1': 0.42333, 'NDCG@3': 0.48416, 'NDCG@5': 0.51037, 'NDCG@10': 0.53789, 'NDCG@100': 0.57592, 'NDCG@1000': 0.59134} {'MAP@1': 0.39944, 'MAP@3': 0.45935, 'MAP@5': 0.47679, 'MAP@10': 0.48894, 'MAP@100': 0.49742, 'MAP@1000': 0.49797} {'Recall@1': 0.39944, 'Recall@3': 0.52561, 'Recall@5': 0.58872, 'Recall@10': 0.67233, 'Recall@100': 0.846, 'Recall@1000': 0.96833} {'P@1': 0.42333, 'P@3': 0.19333, 'P@5': 0.13333, 'P@10': 0.07567, 'P@100': 0.0096, 'P@1000': 0.0011}
# Retriever evaluation for k in: 10
# {'NDCG@1': 0.42333, 'NDCG@3': 0.48416, 'NDCG@5': 0.51037, 'NDCG@10': 0.53789, 'NDCG@100': 0.57592, 'NDCG@1000': 0.59134} {'MAP@1': 0.39944, 'MAP@3': 0.45935, 'MAP@5': 0.47679, 'MAP@10': 0.48894, 'MAP@100': 0.49742, 'MAP@1000': 0.49797} {'Recall@1': 0.39944, 'Recall@3': 0.52561, 'Recall@5': 0.58872, 'Recall@10': 0.67233, 'Recall@100': 0.846, 'Recall@1000': 0.96833} {'P@1': 0.42333, 'P@3': 0.19333, 'P@5': 0.13333, 'P@10': 0.07567, 'P@100': 0.0096, 'P@1000': 0.0011}
# Retriever evaluation for k in: 100
# {'NDCG@1': 0.42333, 'NDCG@3': 0.48416, 'NDCG@5': 0.51037, 'NDCG@10': 0.53789, 'NDCG@100': 0.57592, 'NDCG@1000': 0.59134} {'MAP@1': 0.39944, 'MAP@3': 0.45935, 'MAP@5': 0.47679, 'MAP@10': 0.48894, 'MAP@100': 0.49742, 'MAP@1000': 0.49797} {'Recall@1': 0.39944, 'Recall@3': 0.52561, 'Recall@5': 0.58872, 'Recall@10': 0.67233, 'Recall@100': 0.846, 'Recall@1000': 0.96833} {'P@1': 0.42333, 'P@3': 0.19333, 'P@5': 0.13333, 'P@10': 0.07567, 'P@100': 0.0096, 'P@1000': 0.0011}
# Retriever evaluation for k in: 1000
# {'NDCG@1': 0.42333, 'NDCG@3': 0.48416, 'NDCG@5': 0.51037, 'NDCG@10': 0.53789, 'NDCG@100': 0.57592, 'NDCG@1000': 0.59134} {'MAP@1': 0.39944, 'MAP@3': 0.45935, 'MAP@5': 0.47679, 'MAP@10': 0.48894, 'MAP@100': 0.49742, 'MAP@1000': 0.49797} {'Recall@1': 0.39944, 'Recall@3': 0.52561, 'Recall@5': 0.58872, 'Recall@10': 0.67233, 'Recall@100': 0.846, 'Recall@1000': 0.96833} {'P@1': 0.42333, 'P@3': 0.19333, 'P@5': 0.13333, 'P@10': 0.07567, 'P@100': 0.0096, 'P@1000': 0.0011}

# %%
import random

#### Print top-k documents retrieved ####
top_k = 3

query_id, ranking_scores = random.choice(list(results.items()))
scores_sorted = sorted(ranking_scores.items(), key=lambda item: item[1], reverse=True)
print("Query : %s\n" % queries[query_id])

for rank in range(top_k):
    doc_id = scores_sorted[rank][0]
    # Format: Rank x: ID [Title] Body
    print("Rank %d: %s [%s] - %s\n" % (rank+1, doc_id, corpus[doc_id].get("title"), corpus[doc_id].get("text")))
# Out:
# Query : Sildenafil improves erectile function in men who experience sexual dysfunction as a result of the use of SSRI antidepressants.
#
# Rank 1: 39281140 [Treatment of antidepressant-associated sexual dysfunction with sildenafil: a randomized controlled trial.] - CONTEXT Sexual dysfunction is a common adverse effect of antidepressants that frequently results in treatment noncompliance. OBJECTIVE To assess the efficacy of sildenafil citrate in men with sexual dysfunction associated with the use of selective and nonselective serotonin reuptake inhibitor (SRI) antidepressants. DESIGN, SETTING, AND PATIENTS Prospective, parallel-group, randomized, double-blind, placebo-controlled trial conducted between November 1, 2000, and January 1, 2001, at 3 US university medical centers among 90 male outpatients (mean [SD] age, 45 [8] years) with major depression in remission and sexual dysfunction associated with SRI antidepressant treatment. INTERVENTION Patients were randomly assigned to take sildenafil (n = 45) or placebo (n = 45) at a flexible dose starting at 50 mg and adjustable to 100 mg before sexual activity for 6 weeks. MAIN OUTCOME MEASURES The primary outcome measure was score on the Clinical Global Impression-Sexual Function (CGI-SF); secondary measures were scores on the International Index of Erectile Function, Arizona Sexual Experience Scale, Massachusetts General Hospital-Sexual Functioning Questionnaire, and Hamilton Rating Scale for Depression (HAM-D). RESULTS Among the 90 randomized patients, 93% (83/89) of patients treated per protocol took at least 1 dose of study drug and 85% (76/89) completed week 6 end-point assessments with last observation carried forward analyses. At a CGI-SF score of 2 or lower, 54.5% (24/44) of sildenafil compared with 4.4% (2/45) of placebo patients were much or very much improved (P<.001). Erectile function, arousal, ejaculation, orgasm, and overall satisfaction domain measures improved significantly in sildenafil compared with placebo patients. Mean depression scores remained consistent with remission (HAM-D score < or =10) in both groups for the study duration. CONCLUSION In our study, sildenafil effectively improved erectile function and other aspects of sexual function in men with sexual dysfunction associated with the use of SRI antidepressants. These improvements may allow patients to maintain adherence with effective antidepressant treatment.
#
# Rank 2: 3981244 [Psychobiological Protective Factors Modifying the Association Between Age and Sexual Health in Men: Findings From the Men’s Health 40+ Study] - Sexual health severely decreases with age. For males older than 40 years, erectile dysfunction (ED) is the most common sexual disorder. Although physical and psychological risk factors for ED have been identified, protective factors are yet to be determined. To date, no study has examined endocrine and psychosocial factors in parallel with regard to their modifying effect on the age-related increase in ED. Two hundred and seventy-one self-reporting healthy men aged between 40 and 75 years provided both psychometric data on sexual function and a set of potential psychosocial protective factors, and saliva samples for the analysis of steroid hormones and proinflammatory cytokines. Around 35% of the participants reported at least a mild form of ED. Direct associations with ED were identified for perceived general health, emotional support, relationship quality, intimacy motivation but not for steroid hormones or proinflammatory markers. Moderation analyses for the association between age and ED revealed positive effects for testosterone (T), dehydroepiandrosterone (DHEA), perceived general health, emotional support, intimacy motivation, and a negative effect for interleukin-6 (all p < .05; f2 > .17). Group differences between older men with and without ED emerged for T, DHEA, and psychometric measures such as perceived general health, emotional support, satisfaction with life, and intimacy motivation (all p < .05; d > .3). Both psychosocial and endocrine parameters moderated the association between age and sexual health. Perceived general health, emotional support, intimacy motivation, and relationship quality emerged as psychosocial protective factors against ED. Higher T and DHEA and lower interleukin-6 levels also buffered against an age-related increase in ED.
#
# Rank 3: 4036038 [The rate of change in declining steroid hormones: a new parameter of healthy aging in men?] - Research on healthy aging in men has increasingly focused on age-related hormonal changes. Testosterone (T) decline is primarily investigated, while age-related changes in other sex steroids (dehydroepiandrosterone [DHEA], estradiol [E2], progesterone [P]) are mostly neglected. An integrated hormone parameter reflecting aging processes in men has yet to be identified. 271 self-reporting healthy men between 40 and 75 provided both psychometric data and saliva samples for hormone analysis. Correlation analysis between age and sex steroids revealed negative associations for the four sex steroids (T, DHEA, E2, and P). Principal component analysis including ten salivary analytes identified a principal component mainly unifying the variance of the four sex steroid hormones. Subsequent principal component analysis including the four sex steroids extracted the principal component of declining steroid hormones (DSH). Moderation analysis of the association between age and DSH revealed significant moderation effects for psychosocial factors such as depression, chronic stress and perceived general health. In conclusion, these results provide further evidence that sex steroids decline in aging men and that the integrated hormone parameter DSH and its rate of change can be used as biomarkers for healthy aging in men. Furthermore, the negative association of age and DSH is moderated by psychosocial factors.
